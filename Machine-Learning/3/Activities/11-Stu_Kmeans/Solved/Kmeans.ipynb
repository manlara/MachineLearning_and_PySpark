# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create dummy data
from sklearn.datasets.samples_generator import make_blobs

X, _ = make_blobs(n_samples=500, centers=6,
                            cluster_std=0.70, random_state=0)

# %%
# Plot and show scatter
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
# Create a kmeans model using k = 12
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=12)

# Fit the model to the data
kmeans.fit(X)

# Use the data to predict the clusters
# save the predictions as `predicted_clusters`
predicted_clusters = kmeans.predict(X)

# %%
# Plot the clusters
plt.scatter(X[:, 0], X[:, 1], c=predicted_clusters, s=50, cmap='viridis')
plt.show()

# %%
# Print the cluster centers and cluster labels
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
centers
# Out:
# array([[ 9.38378197, -1.57607057],
#        [ 0.9981184 ,  3.54190857],
#        [-1.41479237,  7.78375031],
#        [ 5.98837982,  0.23312154],
#        [-2.0371292 ,  2.39357843],
#        [ 0.17899717,  4.83728699],
#        [ 1.52847904,  0.89256505],
#        [ 2.65497654,  0.67365674],
#        [ 9.22076262, -2.75495187],
#        [-1.073036  ,  3.22267951],
#        [ 5.59149149,  1.42548284],
#        [ 1.53107884,  4.76484471]])

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

plt.show()
