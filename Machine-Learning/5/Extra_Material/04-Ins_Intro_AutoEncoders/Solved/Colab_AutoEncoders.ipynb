# %% [markdown]
# ## By [@Zaid Alyafeai](https://twitter.com/zaidalyafeai)

# %%
#for creating the gif images 
# !pip install imageio
# Out:
# Requirement already satisfied: imageio in /usr/local/lib/python3.6/dist-packages (2.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from imageio) (1.17.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from imageio) (4.3.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->imageio) (0.46)

# %% [markdown]
# # AutoEncoders
#
# Autoencoders automatically consists of two structures: the encoder and the decoder. The encoder network downsamples the data into lower dimensions and the decoder network reconstructs the original data from the lower dimension representation. The lower dimension representation is usually called latent space representation.

# %% [markdown]
# ![alt text](https://cdn-images-1.medium.com/max/1000/1*8ixTe1VHLsmKB3AquWdxpQ.png)

# %%
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
from keras import backend as K
import imageio
import glob 
import os
import cv2
import numpy as np
from keras import regularizers
from keras.datasets import mnist
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %% [markdown]
# # QuickDraw10
#
# This is a simpler version of the QuickDraw [dataset](https://github.com/googlecreativelab/quickdraw-dataset) with only 10 classes.

# %%
# !git clone https://github.com/zaidalyafeai/QuickDraw10
# Out:
# Cloning into 'QuickDraw10'...
# remote: Enumerating objects: 53, done.
# remote: Total 53 (delta 0), reused 0 (delta 0), pack-reused 53
# Unpacking objects: 100% (53/53), done.

# %%
import numpy as np

train_data = np.load('QuickDraw10/dataset/train-ubyte.npz')
test_data  = np.load('QuickDraw10/dataset/test-ubyte.npz')

x_train, y_train = train_data['a'], test_data['b']
x_test,  y_test  = test_data['a'],  test_data['b']

# %%
x_train = np.expand_dims(x_train.astype('float32') / 255., 3)
x_test =  np.expand_dims(x_test.astype('float32') / 255. , 3)

print (x_train.shape)
print (x_test.shape)
# Out:
# (80000, 28, 28, 1)
# (20000, 28, 28, 1)

# %%
def create_layers():
  layers = []
  size = 32 
  
  #encoder layers
  for i in range(0, 3):
    x = Conv2D(size, (3, 3), activation='relu', padding='same')
    layers += [x] 
    x = MaxPooling2D((2, 2), padding='same')
    layers += [x]
    size = size // 2
  

  #deocder layers 
  for i in range(0, 3):
    size = size * 2
    if i == 2:
      x = Conv2D(size, (3, 3), activation='relu')
    else:
      x = Conv2D(size, (3, 3), activation='relu', padding='same')
    layers += [x]
    x = UpSampling2D((2, 2))
    layers += [x]
    
    
  x = Conv2D(1, (3, 3), activation='sigmoid', padding='same')
  layers += [x]
  
  return layers

def autoencoder():
  input_img = Input(shape=(28, 28, 1))  

  layers = create_layers()

  #create the auto encoder network 
  x = input_img
  for layer in layers:
    x = layer(x)
    
  autoencoder = Model(input_img, x)
  autoencoder.compile(optimizer = 'adam', loss = 'binary_crossentropy')
  
  #create the encoder network
  x = input_img
  for layer in layers[0:6]:
    x = layer(x)
    
  encoder = Model(input_img, x)
  
  #create the decoder network
  input_encoded = Input(shape = (4, 4, 8))
  x = input_encoded
  for layer in layers[6:]:
    x = layer(x)

  decoder = Model(input_encoded, x)
  return autoencoder, encoder, decoder

# %%
autoencoder, encoder, decoder = autoencoder()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/100
# 80000/80000 [==============================] - 15s 194us/sample - loss: 0.2984 - val_loss: 0.2484
# Epoch 2/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.2379 - val_loss: 0.2289
# Epoch 3/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.2236 - val_loss: 0.2186
# Epoch 4/100
# 80000/80000 [==============================] - 8s 104us/sample - loss: 0.2155 - val_loss: 0.2121
# Epoch 5/100
# 80000/80000 [==============================] - 8s 105us/sample - loss: 0.2098 - val_loss: 0.2094
# Epoch 6/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.2053 - val_loss: 0.2032
# Epoch 7/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.2017 - val_loss: 0.2019
# Epoch 8/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1987 - val_loss: 0.1970
# Epoch 9/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1962 - val_loss: 0.1970
# Epoch 10/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1939 - val_loss: 0.1930
# Epoch 11/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1920 - val_loss: 0.1913
# Epoch 12/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1902 - val_loss: 0.1898
# Epoch 13/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1887 - val_loss: 0.1880
# Epoch 14/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1873 - val_loss: 0.1887
# Epoch 15/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1860 - val_loss: 0.1858
# Epoch 16/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1849 - val_loss: 0.1850
# Epoch 17/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1839 - val_loss: 0.1834
# Epoch 18/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1828 - val_loss: 0.1824
# Epoch 19/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1820 - val_loss: 0.1829
# Epoch 20/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1811 - val_loss: 0.1806
# Epoch 21/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1803 - val_loss: 0.1805
# Epoch 22/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1796 - val_loss: 0.1793
# Epoch 23/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1790 - val_loss: 0.1790
# Epoch 24/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1783 - val_loss: 0.1787
# Epoch 25/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1778 - val_loss: 0.1778
# Epoch 26/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1774 - val_loss: 0.1775
# Epoch 27/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1769 - val_loss: 0.1766
# Epoch 28/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1765 - val_loss: 0.1765
# Epoch 29/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1760 - val_loss: 0.1757
# Epoch 30/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1757 - val_loss: 0.1764
# Epoch 31/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1753 - val_loss: 0.1754
# Epoch 32/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1751 - val_loss: 0.1750
# Epoch 33/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1747 - val_loss: 0.1769
# Epoch 34/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1743 - val_loss: 0.1750
# Epoch 35/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1741 - val_loss: 0.1741
# Epoch 36/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1738 - val_loss: 0.1736
# Epoch 37/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1734 - val_loss: 0.1734
# Epoch 38/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1732 - val_loss: 0.1736
# Epoch 39/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1730 - val_loss: 0.1729
# Epoch 40/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1727 - val_loss: 0.1725
# Epoch 41/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1725 - val_loss: 0.1722
# Epoch 42/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1721 - val_loss: 0.1726
# Epoch 43/100
# 80000/80000 [==============================] - 8s 104us/sample - loss: 0.1719 - val_loss: 0.1721
# Epoch 44/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1717 - val_loss: 0.1715
# Epoch 45/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1715 - val_loss: 0.1719
# Epoch 46/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1712 - val_loss: 0.1711
# Epoch 47/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1712 - val_loss: 0.1720
# Epoch 48/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1709 - val_loss: 0.1705
# Epoch 49/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1707 - val_loss: 0.1714
# Epoch 50/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1706 - val_loss: 0.1702
# Epoch 51/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1704 - val_loss: 0.1704
# Epoch 52/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1701 - val_loss: 0.1708
# Epoch 53/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1700 - val_loss: 0.1705
# Epoch 54/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1699 - val_loss: 0.1699
# Epoch 55/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1696 - val_loss: 0.1694
# Epoch 56/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1696 - val_loss: 0.1699
# Epoch 57/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1693 - val_loss: 0.1700
# Epoch 58/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1692 - val_loss: 0.1693
# Epoch 59/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1691 - val_loss: 0.1702
# Epoch 60/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1689 - val_loss: 0.1688
# Epoch 61/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1687 - val_loss: 0.1698
# Epoch 62/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1687 - val_loss: 0.1689
# Epoch 63/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1685 - val_loss: 0.1688
# Epoch 64/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1684 - val_loss: 0.1686
# Epoch 65/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1681 - val_loss: 0.1686
# Epoch 66/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1682 - val_loss: 0.1686
# Epoch 67/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1680 - val_loss: 0.1679
# Epoch 68/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1679 - val_loss: 0.1683
# Epoch 69/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1677 - val_loss: 0.1677
# Epoch 70/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1676 - val_loss: 0.1674
# Epoch 71/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1675 - val_loss: 0.1675
# Epoch 72/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1674 - val_loss: 0.1673
# Epoch 73/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1673 - val_loss: 0.1671
# Epoch 74/100
# 80000/80000 [==============================] - 8s 101us/sample - loss: 0.1672 - val_loss: 0.1678
# Epoch 75/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1672 - val_loss: 0.1669
# Epoch 76/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1669 - val_loss: 0.1674
# Epoch 77/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1668 - val_loss: 0.1675
# Epoch 78/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1667 - val_loss: 0.1666
# Epoch 79/100
# 80000/80000 [==============================] - 8s 105us/sample - loss: 0.1666 - val_loss: 0.1669
# Epoch 80/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1666 - val_loss: 0.1678
# Epoch 81/100
# 80000/80000 [==============================] - 8s 104us/sample - loss: 0.1664 - val_loss: 0.1672
# Epoch 82/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1664 - val_loss: 0.1663
# Epoch 83/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1662 - val_loss: 0.1663
# Epoch 84/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1661 - val_loss: 0.1660
# Epoch 85/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1660 - val_loss: 0.1663
# Epoch 86/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1660 - val_loss: 0.1661
# Epoch 87/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1659 - val_loss: 0.1657
# Epoch 88/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1658 - val_loss: 0.1660
# Epoch 89/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1657 - val_loss: 0.1663
# Epoch 90/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1657 - val_loss: 0.1662
# Epoch 91/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1655 - val_loss: 0.1658
# Epoch 92/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1654 - val_loss: 0.1653
# Epoch 93/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1653 - val_loss: 0.1655
# Epoch 94/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1653 - val_loss: 0.1659
# Epoch 95/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1652 - val_loss: 0.1656
# Epoch 96/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1651 - val_loss: 0.1675
# Epoch 97/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1651 - val_loss: 0.1654
# Epoch 98/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1649 - val_loss: 0.1650
# Epoch 99/100
# 80000/80000 [==============================] - 8s 103us/sample - loss: 0.1649 - val_loss: 0.1651
# Epoch 100/100
# 80000/80000 [==============================] - 8s 102us/sample - loss: 0.1648 - val_loss: 0.1650

# %% [markdown]
# # Interpolate Between a Batch of Images

# %% [markdown]
# Given two images $x_1, x_2$ we want to interpolate between their latent space representations to create some nice affects. The basic idea is that we calculate $v_1 = encoder(x_1)$ and $v_2 = encoder(x_2)$  then we calculate the combination vector $v = x v_1 + (1-x)v_2$ where $x\in [0, 1]$ . Each time we increase the value of the varible $x$ the decoder move from a reconstruction of $x_1$ to a reconstruction of $x_2$. Note that we are using a linear combination here.

# %%
import shutil 

#linear interpolation function 
def f(x):
  return x

def interpolate(size = 10):
  if os.path.exists("images"):
    shutil.rmtree("images")
    os.makedirs('images')
  else:
    os.makedirs('images')
    
  
  
  #get 3 random batches each of size 3 
  batches = []
  for _ in range(0, 3):
    i1 = np.random.randint(0, len(x_train))
    i2 = np.random.randint(0, len(x_train))
    batches.append([x_train[i1:i1+3], x_train[i2:i2+3]])
 
  i = 0   
  for x in list(np.linspace(0, 1, size)):
    frame = None
    j = 0 
    
    #interpolate each batch and concatenate them at the end to create 3x3 images
    for (x1, x2) in batches:
    
      
      v1 = encoder.predict(x1) 
      v2 = encoder.predict(x2)
        
      #use a linear interpolater 
      v = f(x) * v1 + f(1-x) * v2
      
      #get the output and reshape it 
      y = decoder.predict(v)
      img = np.reshape(y, (3 * 28, 28))
      img = img * 255
      
      #concatenate the batches 
      if frame is None:
        frame = img
      else:
        frame = np.concatenate([frame, img], axis = 1)
      j += 1
      
    #write the current frame to the disk 
    frame = cv2.resize(frame, (256, 256))  
    cv2.imwrite(f'images/image{i}.png', frame)
    i+=1

# %%
interpolate(size = 10)

# %% [markdown]
# # Create a gif of the interpolated images

# %%
with imageio.get_writer('lsi.gif', mode='I', duration=0.35) as writer:
  filenames = glob.glob('images/image*.png')
  filenames = sorted(filenames)
  
  for i,filename in enumerate(filenames):
    image = imageio.imread(filename)
    writer.append_data(image)
    
# this is a hack to display the gif inside the notebook
os.system('cp lsi.gif lsi.gif.png')
# Out:
# 0

# %%
from IPython import display 
display.Image(filename="lsi.gif.png")

# %% [markdown]
# # References
#
#
# *   https://hackernoon.com/autoencoders-deep-learning-bits-1-11731e200694
# *   https://blog.keras.io/building-autoencoders-in-keras.html
